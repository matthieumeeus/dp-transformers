# %%
import pandas as pd
import numpy as np
from privacy_estimates.experiments.aml import Job
from datasets import Dataset

# %%
results = Dataset.from_pandas(pd.DataFrame(data=[
    {"dataset": "agnews", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/wheat_cumin_m98ldw31zp?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "agnews", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/epic_tomato_143ms1f3qz?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "agnews", "canary_method": "in", "canary_label": None, "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/ashy_berry_12pc7v4v25?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "sst2", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/e2058cb6-5182-4b06-9ba6-410257991c33?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "sst2", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/tender_fowl_jp7svhg3fk?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "sst2", "canary_method": "in", "canary_label": None, "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/epic_pipe_pf261j4vlb?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/ppml/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "sst2", "canary_method": None, "canary_label": None, "mi_method": "1_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/zen_snake_slvm11ml7l?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "sst2", "canary_method": None, "canary_label": None, "mi_method": "3_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/shy_stick_q1lthsvqxd?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "sst2", "canary_method": None, "canary_label": None, "mi_method": "4_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/teal_card_9ddjh3n6ts?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": None, "canary_label": None, "mi_method": "1_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/amusing_pipe_3cn7zcy39y?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": None, "canary_label": None, "mi_method": "3_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/gray_cherry_3hs9fqb3n7?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": None, "canary_label": None, "mi_method": "4_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/modest_mangos_3pkvq81jvy?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47#"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/clever_soccer_7yj3ccmqzq?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourcegroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/green_card_99nppp3p15?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourcegroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "in", "canary_label": None, "mi_method": "2_gram", "eps": float("inf"), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/kind_drawer_pdc15y0m9z?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourcegroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "sst2", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/serene_jelly_xh5q744c7c?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "sst2", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/lucid_lettuce_8hqvn63h5m?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "sst2", "canary_method": "in", "canary_label": None, "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/goofy_nutmeg_y7tdsr9gbh?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/olive_comb_65hqrtrx14?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/wheat_car_tc5h1j1x6h?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "agnews", "canary_method": "in", "canary_label": None, "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/kind_feast_ckwqf8th7c?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "uni", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/funny_seed_mlrm6jmbjk?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "can", "mi_method": "2_gram", "eps": 8, "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/cool_bell_w7w4qm5l2r?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "in", "canary_label": None, "mi_method": "jac", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/quirky_market_13vrbk9v14?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "can", "mi_method": "jac", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/olive_wheel_118czvxc8l?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "uni", "mi_method": "jac", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/upbeat_dress_c5yzx0z0dw?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "in", "canary_label": None, "mi_method": "emb", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/orange_pummelo_3cwxj8vftx?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "can", "mi_method": "emb", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/stoic_plastic_8xbft096t0?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
    {"dataset": "snli", "canary_method": "synth", "canary_label": "uni", "mi_method": "emb", "eps": float('inf'), "url": "https://ml.azure.com/experiments/id/cbd45cd3-4fd8-4922-b82a-124527cc98ee/runs/icy_rhythm_4kr0tstkgq?wsid=/subscriptions/acc09744-1ee3-4242-b375-93421c63af0c/resourceGroups/PPML/providers/Microsoft.MachineLearningServices/workspaces/M365Research-PPML-EUS&tid=72f988bf-86f1-41af-91ab-2d7cd011db47"},
]))

# %%
def get_metrics(url: str):
    job = Job.from_url(url)
    estimates = job.get_node("estimate_privacy")
    metrics = estimates.get_metrics()
    fpr = np.array(metrics["trade_off_curves"]["fpr"])
    tpr = 1 - np.array(metrics["trade_off_curves"]["roc"])
    tpr_0_01 = np.interp(0.01, fpr, tpr)
    tpr_0_1 = np.interp(0.1, fpr, tpr)
    auc = np.trapz(tpr, fpr)
    return {"fpr": fpr, "tpr": tpr, "auc": auc, "tpr@0.01": tpr_0_01, "tpr@0.1": tpr_0_1}

# %%
results = results.map(get_metrics, input_columns=["url"])

# %%
results.remove_columns(["url", "fpr", "tpr"]).to_pandas()
